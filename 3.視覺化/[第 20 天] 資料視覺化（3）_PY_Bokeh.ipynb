# %% [markdown]
# http://ithelp.ithome.com.tw/articles/10186749

# %% [markdown]
# # 基本的圖形，包括：
#
# + 直方圖（Histogram）
# + 散佈圖（Scatter plot）
# + 線圖（Line plot）
# + 長條圖（Bar plot）
# + 盒鬚圖（Box plot）

# %% [markdown]
# ## 直方圖（Histogram）
#
# Python
#
# 使用 bokeh.charts 的 Histogram() 方法。

# %%
from bokeh.plotting import output_notebook
from bokeh.charts import Histogram, show
import numpy as np

normal_samples = np.random.normal(size = 100000) # 生成 100000 組標準常態分配（平均值為 0，標準差為 1 的常態分配）隨機變數

output_notebook()

hist = Histogram(normal_samples)
show(hist, notebook_handle = True )
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="8d25750f-d7b7-4472-8606-c3a624823bc0">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="43761a35-03e7-42ce-b990-aa6dbfc18dc6"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("43761a35-03e7-42ce-b990-aa6dbfc18dc6");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }if ((window.Jupyter !== undefined) && Jupyter.notebook.kernel) {
#       comm_manager = Jupyter.notebook.kernel.comm_manager
#       comm_manager.register_target("6c9fab73-9491-4e51-85b2-fc4f8a4f99a8", function () {});
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("43761a35-03e7-42ce-b990-aa6dbfc18dc6");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '43761a35-03e7-42ce-b990-aa6dbfc18dc6' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"c7efb830-204e-429e-ac43-fa36a9665860":{"roots":{"references":[{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["[-4.453250, -4.395602]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[1.0],"label":["[-4.453250, -4.395602]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.05764783882131752],"x":["-4.424426"],"y":[0.5]}},"id":"5f9aa549-235e-47d7-a491-d2e820bb0179","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a050b625-dbe8-46aa-8f74-3bd369f8d076","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(-3.473237, -3.415589]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[5.0],"label":["(-3.473237, -3.415589]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.05764783882131708],"x":["-3.444413"],"y":[2.5]}},"id":"f77c8446-1814-44b5-8f3f-ce6084e130f7","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"5340ed63-2edf-4bfc-8582-89d25d0bc7bc","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(-4.280307, -4.222659]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[0.0],"label":["(-4.280307, -4.222659]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.05764783882131663],"x":["-4.251483"],"y":[0.0]}},"id":"8796ddd6-d4ad-476f-a254-c821563433a3","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"5f9aa549-235e-47d7-a491-d2e820bb0179","type":"ColumnDataSource"},"glyph":{"id":"a050b625-dbe8-46aa-8f74-3bd369f8d076","type":"Rect"},"hover_glyph":null,"muted_glyph":null},"id":"95473057-3883-4270-8ea2-1cf4349bc42c","type":"GlyphRenderer"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"71b8e459-936a-41ac-b369-662bc9aa7215","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(1.715068, 1.772716]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[520.0],"label":["(1.715068, 1.772716]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.05764783882131752],"x":["1.743892"],"y":[260.0]}},"id":"873c9f63-4d01-4ae2-8b2c-da1ed3a53dda","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"a07004bb-bf53-4391-816c-51863d14dc4f","type":"Rect"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"0c41a035-b7d1-402c-8018-c3cfa2d7e1fb","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":["(2.464490, 2.522138]"],"color":["#f22c40"],"fill_alpha":[0.8],"height":[106.0],"label":["(2.464490, 2.522138]"],"line_alpha":[1.0],"line_color":["black"],"width":[0.05764783882131663],"x":["2.493314"],"y":[53.0]}},"id":"5081c87d-e5ff-4 ...
# <p><code>&lt;Bokeh Notebook handle for <strong>In[13]</strong>&gt;</code></p>

# %% [markdown]
# ## 散佈圖（Scatter plot）
#
# Python
#
# 使用 bokeh.charts 的 Scatter() 方法。

# %%
from bokeh.plotting import output_notebook
from bokeh.charts import Scatter, show
import pandas as pd

output_notebook()

speed = [4, 4, 7, 7, 8, 9, 10, 10, 10, 11, 11, 12, 12, 12, 12, 13, 13, 13, 13, 14, 14, 14, 14, 15, 15, 15, 16, 16, 17, 17, 17, 18, 18, 18, 18, 19, 19, 19, 20, 20, 20, 20, 20, 22, 23, 24, 24, 24, 24, 25]
dist = [2, 10, 4, 22, 16, 10, 18, 26, 34, 17, 28, 14, 20, 24, 28, 26, 34, 34, 46, 26, 36, 60, 80, 20, 26, 54, 32, 40, 32, 40, 50, 42, 56, 76, 84, 36, 46, 68, 32, 48, 52, 56, 64, 66, 54, 70, 92, 93, 120, 85]

cars_df = pd.DataFrame(
    {"speed": speed,
     "dist": dist
    }
)

scatter = Scatter(cars_df, x = "speed", y = "dist")
show(scatter)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="
type":"LinearAxis"},{"attributes":{"plot":null,"text":null},"id":"c2a4292c-4a84-47da-8e41-edc6c187e329","type":"Title"},{"attributes":{"axis_label":"dist","formatter":{"id":"b3d7cd86-2e40-434c-a7d9-a49d9fd40672","type":"BasicTickFormatter"},"plot":{"id":"4c8d0f30-e8ec-4e4a-94e9-dc12d91eec10","subtype":"Chart","type":"Plot"},"ticker":{"id":"9b130cd7-8b7f-45a8-863c-f9ef4f71e33c","type":"BasicTicker"}},"id":"36504eb0-20e2-421b-b90c-71f0b4c2541c","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"e07e210e-44da-44c7-96c9-520f8e2c833f","type":"PanTool"},{"id":"e2e0760b-3cec-4e4c-b54d-4c72d4e5b301","type":"WheelZoomTool"},{"id":"553a050c-7b9e-413d-bb17-6324e7450405","type":"BoxZoomTool"},{"id":"919be988-aff7-47de-9e1e-530316bdd07c","type":"SaveTool"},{"id":"386e0089-4f20-4a13-962d-f7e0650dddbd","type":"ResetTool"},{"id":"7e19326d-e508-4f7d-a627-3885ae8d3d42","type":"HelpTool"}]},"id":"72eb6ef1-3b0c-4358-addb-5da2ce6eb0e8","type":"Toolbar"},{"attributes":{},"id":"b3d7cd86-2e40-434c-a7d9-a49d9fd40672","type":"BasicTickFormatter"},{"attributes":{},"id":"2804bca2-fb42-4f93-bda1-4ff4c69b8fcf","type":"BasicTicker"},{"attributes":{"location":"top_left","plot":{"id":"4c8d0f30-e8ec-4e4a-94e9-dc12d91eec10","subtype":"Chart","type":"Plot"}},"id":"e47fb8f7-c611-41f7-ac3d-a0986cc80a86","type":"Legend"},{"attributes":{},"id":"d00064bc-be0c-4a4c-930a-eb99447a5917","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"4c8d0f30-e8ec-4e4a-94e9-dc12d91eec10","subtype":"Chart","type":"Plot"},"ticker":{"id" ...

# %% [markdown]
# ## 線圖（Line plot）
#
# Python
#
# 使用 bokeh.charts 的 Line() 方法。

# %%
from bokeh.charts import Line, show, output_notebook
import pandas as pd

output_notebook()

speed = [4, 4, 7, 7, 8, 9, 10, 10, 10, 11, 11, 12, 12, 12, 12, 13, 13, 13, 13, 14, 14, 14, 14, 15, 15, 15, 16, 16, 17, 17, 17, 18, 18, 18, 18, 19, 19, 19, 20, 20, 20, 20, 20, 22, 23, 24, 24, 24, 24, 25]
dist = [2, 10, 4, 22, 16, 10, 18, 26, 34, 17, 28, 14, 20, 24, 28, 26, 34, 34, 46, 26, 36, 60, 80, 20, 26, 54, 32, 40, 32, 40, 50, 42, 56, 76, 84, 36, 46, 68, 32, 48, 52, 56, 64, 66, 54, 70, 92, 93, 120, 85]

cars_df = pd.DataFrame(
    {"speed": speed,
     "dist": dist
    }
)

line = Line(cars_df, x = "speed", y = "dist")
show(line)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="9bcb31dd-e961-45f6-aaa8-3bb57807af9d">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="8dde812e-19ae-43f0-b827-0701906948c1"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("8dde812e-19ae-43f0-b827-0701906948c1");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("8dde812e-19ae-43f0-b827-0701906948c1");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '8dde812e-19ae-43f0-b827-0701906948c1' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"55449515-decc-44b1-9c09-2837c3544a47":{"roots":{"references":[{"attributes":{"plot":null,"text":null},"id":"2f41a575-7a69-4fc7-ae58-b950262960e2","type":"Title"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"878f90b3-0613-4410-b013-d77c6db1378a","type":"PanTool"},{"id":"c68221af-a54e-4f8c-a031-fd18cd268d0e","type":"WheelZoomTool"},{"id":"648eda35-68cb-47af-921c-817bd62befcc","type":"BoxZoomTool"},{"id":"e6cfe860-dea6-456d-bb55-23dec6421329","type":"SaveTool"},{"id":"f018c4c1-9179-4839-8d73-507d86a202ff","type":"ResetTool"},{"id":"c594a100-1366-4a7d-aadc-41a6638dd97a","type":"HelpTool"}]},"id":"5fd173af-0a01-479e-b5a0-f683859628fb","type":"Toolbar"},{"attributes":{"axis_label":"speed","formatter":{"id":"e8937a99-6ff4-42da-b811-b8e6dfb49ef0","type":"BasicTickFormatter"},"plot":{"id":"5b946668-a262-442b-a245-d7d17ee72a78","subtype":"Chart","type":"Plot"},"ticker":{"id":"e256bf0d-25d5-42a5-8d31-8c53052cc28c","type":"BasicTicker"}},"id":"5dd81188-2d77-4ed6-ac2a-17e0f3702519","type":"LinearAxis"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"a105a35b-ef8d-4bb3-9414-47f1b2f8e858","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"5b946668-a262-442b-a245-d7d17ee72a78","subtype":"Chart","type":"Plot"}},"id":"878f90b3-0613-4410-b013-d77c6db1378a","type":"PanTool"},{"attributes":{},"id":"e8937a99-6ff4-42da-b811-b8e6dfb49ef0","type":"BasicTickFormatter"},{"attributes":{"plot":{"id":"5b946668-a262-442b-a245-d7d17ee72a78","subtype":"Chart","type":"Plot"}},"id":"c68221af-a54e-4f8c-a031-fd18cd268d0e","type":"WheelZoomTool"},{"attributes":{},"id":"4939cd03-e6df-4873-9758-57e5a76d37a4","type":"BasicTickFormatter"},{"attributes":{"overlay":{"id":"a105a35b-ef8d-4bb3-9414-47f1b2f8e858","type":"BoxAnnotation"},"plot":{"id":"5b946668-a262-442b-a245-d7d17ee72a78","subtype":"Chart","type":"Plot"}},"id":"648eda35-68cb-47af-921c-817bd62befcc","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"5b946668-a262-442b-a245-d7d17ee72a78","subtype":"Chart","type":"Plot"}},"id":"e6cfe860-dea6-456d-bb55-23dec6421329","type":"SaveTool"},{"attributes":{"plot":{"id":"5b946668-a262-442b-a245-d7d17ee72a78","subtype":"Chart","type":"Plot"}},"id":"f018c4c1-9179-4839-8d73-507d86a202ff","type":"ResetTool"},{"attributes":{"plot":{"id":"5b946668-a262-442b-a245-d7d17ee72a78","subtype":"Chart","type":"Plot"}},"id":"c594a100-1366-4a7d-aadc-41a6638dd97a","type":"HelpTool"},{"attributes":{"callback":null,"column_names":["x_values","y_values"],"data":{"chart_index":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"x_values":[4,4,7,7,8,9,10,10,10,11,11,12,12,12,12,13,13,13,13,14,14,14,14,15,15,15,16,16,17,17,17,18,18,18,18,19,19,19,20,20,20,20,20,22,23,24,24,24,24,25],"y_values":[2,10,4,22,16,10,18,26,34,17,28,14,20,24,28,26,34,34,46,26,36,60,80,20,26,54,32,40,32,40,50,42,56,76,84,36,46,68,32,48,52,56,64,66,54,70,92,93,120,85]}},"id":"6bcd2f1a-713f-4001-9dbf-a26799c5c2d4","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"6bcd2f1a-713f-4001-9dbf-a26799c5c2d4","type":"ColumnDataSource"},"glyph":{"id":"26e0959f-975e-40eb-806b-2c6ce3d752a8","type":"Line"},"hover_glyph":null,"muted_glyph":null},"id":"85c375b6-fcbd-4ba8-884c-223e2bc8f127","type":"GlyphRenderer"},{"attributes":{"location":"top_left","plot":{"id":"5b946668-a262-442b-a245-d7d17ee72a78","subtype":"Chart","type":"Plot"}},"id":"f50d34d9-1135-4362-a48e-2db083507ac5","type":"Legend"},{"attributes":{"callback":null,"end":27.1,"start":1.9},"id":"effc556a-f075-4ef6-a ...

# %% [markdown]
# ## 長條圖（Bar plot）
#
# Python
#
# 使用 bokeh.charts 的 Bar() 方法。

# %%
from bokeh.charts import Bar, show, output_notebook
import pandas as pd

cyls = [11, 7, 14]
labels = ["4", "6", "8"]
cyl_df = pd.DataFrame({
    "cyl": cyls,
    "label": labels
})

bar = Bar(cyl_df, values = "cyl", label = "label")
show(bar)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="
type":"Toolbar"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"36af1b00-2eb0-4d62-984d-589adf07520a","type":"Rect"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"8"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[14.0],"label":["8"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["8"],"y":[7.0]}},"id":"1117b597-fb59-4482-bdfd-67f68f4e7d0f","type":"ColumnDataSource"},{"attributes":{"label":{"value":"6"},"renderers":[{"id":"fdf7fd0e-43a5-4c6f-a5a6-1e2801569c1d","type":"GlyphRenderer"}]},"id":"28f807f9-2f81-45ea-91e6-472fea03a9f9","type":"LegendItem"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"label":"6"}],"color":["#f22c40"],"fill_alpha":[0.8],"height":[7.0],"label":["6"],"line_alpha":[1.0],"line_color":["white"],"width":[0.8],"x":["6"],"y":[3.5]}},"id":"53e3a01e-694c-43ff-a9b9-d9e4d62c6c75","type":"ColumnDataSource"},{"attributes":{"axis_label":"Label","formatter":{"id":"5cf84f18-174b-4350-8562-5d22927c5cd6","type":"CategoricalTickFormatter"},"major_label_orientation":0.7853981633974483,"plot":{"id":"2baaab1f-9284-455d-8f52-5955d0da3f9c","subtype":"Chart","type":"Plot"},"ticker":{"id":"cd386a72-7add-4e98-ad71-08d214b1d6f9","type":"CategoricalTic ...

# %% [markdown]
# ## 盒鬚圖（Box plot）
#
# Python
#
# 使用 bokeh.charts 的 BoxPlot() 方法。

# %%
from bokeh.charts import BoxPlot, show, output_notebook
import pandas as pd

output_notebook()

mpg = [21, 21, 22.8, 21.4, 18.7, 18.1, 14.3, 24.4, 22.8, 19.2, 17.8, 16.4, 17.3, 15.2, 10.4, 10.4, 14.7, 32.4, 30.4, 33.9, 21.5, 15.5, 15.2, 13.3, 19.2, 27.3, 26, 30.4, 15.8, 19.7, 15, 21.4]
cyl = [6, 6, 4, 6, 8, 6, 8, 4, 4, 6, 6, 8, 8, 8, 8, 8, 8, 4, 4, 4, 4, 8, 8, 8, 8, 4, 4, 4, 8, 6, 8, 4]
mtcars_df = pd.DataFrame({
    "mpg": mpg,
    "cyl": cyl
})

box = BoxPlot(mtcars_df, values = "mpg", label = "cyl")
show(box)
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1573be70-45f1-409b-b09c-7c232b2970a7">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="efac1149-0809-4124-a24e-381da8c47661"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("efac1149-0809-4124-a24e-381da8c47661");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("efac1149-0809-4124-a24e-381da8c47661");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'efac1149-0809-4124-a24e-381da8c47661' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"2d66a919-0ec2-42a7-837c-eb7546984702":{"roots":{"references":[{"attributes":{},"id":"2b8edd3f-7a8a-437a-a508-df371bfec18b","type":"ToolEvents"},{"attributes":{"axis_label":"Mpg","formatter":{"id":"a44df598-13ac-479b-8001-e2674692ffab","type":"BasicTickFormatter"},"plot":{"id":"5d499fa8-23c2-4393-a39d-d3e36a1745cb","subtype":"Chart","type":"Plot"},"ticker":{"id":"d0421a60-a7c9-4796-ad68-6b9171731da4","type":"BasicTicker"}},"id":"0d1a52c4-db7e-4de5-8a82-c7a2ac9f8c85","type":"LinearAxis"},{"attributes":{"data_source":{"id":"8dedff82-03fa-469a-9a0c-b319e886fc69","type":"ColumnDataSource"},"glyph":{"id":"17b24be2-9a4b-406b-8bca-4ae02425c6e1","type":"Circle"},"hover_glyph":null,"muted_glyph":null},"id":"5c6d1c68-906d-4ade-b256-f4f8c60c61d4","type":"GlyphRenderer"},{"attributes":{"callback":null,"column_names":["x","y","width","height","color","fill_alpha","line_color","line_alpha","label"],"data":{"chart_index":[{"cyl":4}],"color":["DimGrey"],"cyl":[4],"fill_alpha":[0.8],"height":[3.1999999999999993],"label":[{"cyl":4}],"line_alpha":[1.0],"line_color":["black"],"width":[0.8],"x":